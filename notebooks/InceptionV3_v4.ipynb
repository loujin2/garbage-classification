# %% [markdown]
# <a href="https://colab.research.google.com/github/SalmanRafiullah/garbage-classification/blob/master/InceptionV3_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Garbage classification:** InceptionV3

# %% [markdown]
# ## Installing libraries

# %%
#Import necessary libraries
from keras.applications.inception_v3 import InceptionV3
from keras_preprocessing.image import ImageDataGenerator
import keras
from keras.models import Sequential
from keras import optimizers, losses
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import pickle
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from google.colab import drive, files
import os
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
from skimage.io import imread_collection
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import load_model
import random

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Mount Drive

# %%
#Mount Google Drive
drive.mount('/content/drive')
""
#Assign directory path for test, train and validation data
test_data_dir = '/content/drive/My Drive/split-garbage-dataset/split-garbage-dataset/test'
train_data_dir = '/content/drive/My Drive/split-garbage-dataset/split-garbage-dataset/train'
valid_data_dir = '/content/drive/My Drive/split-garbage-dataset/split-garbage-dataset/valid'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Load data as ImageDataGenerator and images

# %%
#Define labels
LABELS = ["trash", "plastic", "paper", "metal", "glass", "cardboard"]
#Define dictionary
LABELS_NUMBERS_MAP = {k:v for k,v in zip(LABELS, range(len(LABELS)))}
#Define reverse of dictionary
LABELS_NUMBERS_REVERSE ={v: k for k, v in LABELS_NUMBERS_MAP.items()}

# %%
#Load images as ImageDataGenerator with augmentation
train_generator = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True,
        rescale=1. / 255,
        shear_range=0.1,
        zoom_range=0.1,
        width_shift_range=0.1,
        height_shift_range=0.1,
        rotation_range=40,
    ).flow_from_directory(
        directory=train_data_dir,
        target_size=(300, 300),
        class_mode = 'categorical',
        shuffle= False,
    )

#Load validation images from directory
valid_generator = ImageDataGenerator(
        rescale=1 / 255,
    ).flow_from_directory(
        directory=valid_data_dir,
        target_size=(300, 300),
        class_mode = 'categorical',
        shuffle= False,
    )

#Load test images from test directory
test_generator = ImageDataGenerator(
        rescale=1 / 255,
    ).flow_from_directory(
        directory=test_data_dir,
        target_size=(300, 300),
        class_mode = 'categorical',
        shuffle= False,
    )
# Out:
# Found 1768 images belonging to 6 classes.
# Found 328 images belonging to 6 classes.
# Found 431 images belonging to 6 classes.

# %%
#Load images
LOAD_FILES_FROM_DRIVE = False

if not LOAD_FILES_FROM_DRIVE:
    for path in [train_data_dir, valid_data_dir, test_data_dir]:
        image_list = [
            imread_collection(f"{path}/{label}/*.jpg") for label in LABELS
        ]
        X_tmp = np.concatenate(image_list)
        y_tmp = np.concatenate([
            np.full(len(arr), i) for i, arr in enumerate(image_list)
        ])
        data_type = path.split("/")[-1]
        np.save(f"X_{data_type}.npy", X_tmp)
        np.save(f"y_{data_type}.npy", y_tmp)

X_train = np.load("X_train.npy")
y_train = np.load("y_train.npy")
X_valid = np.load("X_valid.npy")
y_valid = np.load("y_valid.npy")
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")

# %% [markdown]
# ## Understanding the data

# %% [markdown]
# ### Visualize sample photos

# %%
#Visualizing sample photos
plt.figure(figsize=[25,15])

for k,i in enumerate(np.random.randint(0, len(X_train), 5)):
    plt.subplot(1,5,k+1)
    plt.imshow(X_train[i])
    plt.xticks(())
    plt.yticks(())
    plt.title(LABELS_NUMBERS_REVERSE[y_train[i]])
    #plt.show()

# %% [markdown]
# ## Build model

# %% [markdown]
# ### Define layers

# %%
#Install tf-nightly
try:
  # %tensorflow_version only exists in Colab.
  # !pip install tf-nightly
except Exception:
  pass
  
import tensorflow as tf


#Define model to train the data on
base_model = InceptionV3(weights=None, include_top=False, input_shape=(300, 300, 3))
#Loading pretrained weights as Trasnsfer Learning fro Inception V3
#https://www.kaggle.com/careyai/inceptionv3-full-pretrained-model-instructions
base_model.load_weights('/content/drive/My Drive/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5')
base_model.trainable = False
#Defining layers for model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.15),
    #Conv2D(1024,3, strides = 2, padding="same", activation='relu'),
    Dense(1024, activation='relu'),
    Dropout(0.15),
    #Flatten(),
    Dense(6, activation='softmax')
])
# Out:
# Collecting tf-nightly
#   Downloading https://files.pythonhosted.org/packages/a2/74/ad6fe36fc7a93333df3b19f85cd7e943d9dca426f33a9d281ed55a3ccf74/tf_nightly-2.2.0.dev20200323-cp36-cp36m-manylinux2010_x86_64.whl (533.1MB)
#      |████████████████████████████████| 533.1MB 23kB/s
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (0.34.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (3.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (1.1.0)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading https://files.pythonhosted.org/packages/60/06/cafdd44889200e5438b897388f3075b52a8ef01f28a17366d91de0fa2d05/h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 35.4MB/s
# Collecting tb-nightly<2.3.0a0,>=2.2.0a0
#   Downloading https://files.pythonhosted.org/packages/79/cd/90edb987326c277e185ca07b1c976459cf83aec9ba859246fca7dc0b893f/tb_nightly-2.2.0a20200323-py3-none-any.whl (2.8MB)
#      |████████████████████████████████| 2.8MB 32.4MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (1.24.3)
# Collecting astunparse==1.6.3
#   Downloading https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (0.9.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (3.10.0)
# Collecting gast==0.3.3
#   Downloading https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (1.4.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (1.18.2)
# Collecting tf-estimator-nightly
#   Downloading https://files.pythonhosted.org/packages/71/85/b57b4a6de25457c260b2915915412872f0bd50e15113c361ea081d6dd036/tf_estimator_nightly-2.3.0.dev2020032301-py2.py3-none-any.whl (455kB)
#      |████████████████████████████████| 460kB 22.2MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tf-nightly) (0.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (46.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (1.0.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/41/ec/3da49289b93963bd8b32d29ed108f1809436ff3d9cd4e29c90bac4a7292f/tensorboard_plugin_wit-1.6.0.post2-py3-none-any.whl (775kB)
#      |████████████████████████████████| 778kB 22.1MB/s
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (2.21.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (1.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (3.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (1.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (4.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tb-nightly<2.3.0a0,>=2.2.0a0->tf-nightly) (0.4.8)
# ERROR: tensorflow 1.15.0 has requirement gast==0.2.2, but you'll have gast 0.3.3 which is incompatible.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow~=2.1.0, but you'll have tensorflow 1.15.0 which is incompatible.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# Installing collected packages: h5py, tensorboard-plugin-wit, tb-nightly, astunparse, gast, tf-estimator-nightly, tf-nightly
#   Found existing installation: h5py 2.8.0
#     Uninstalling h5py-2.8.0:
#       Successfully uninstalled h5py-2.8.0
#   Found existing installation: gast 0.2.2
#     Uninstalling gast-0.2.2:
#       Successfully uninstalled gast-0.2.2
# Successfully installed astunparse-1.6.3 gast-0.3.3 h5py-2.10.0 tb-nightly-2.2.0a20200323 tensorboard-plugin-wit-1.6.0.post2 tf-estimator-nightly-2.3.0.dev2020032301 tf-nightly-2.2.0.dev20200323
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Compile model

# %%
#Define optimizer and learning rate
opt = optimizers.nadam(lr=0.001)
#Compile the model
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy'])
#Print model summary
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 23,907,110
# Trainable params: 2,104,326
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
#Define model parameters
batch_size = 200
epochs = 200
patience = 10

steps_per_epoch = train_generator.n // batch_size
validation_steps = valid_generator.n // batch_size

#Define location to store models
filepath = "/content/drive/My Drive/model/model_{epoch:02d}-{acc:.2f}-{val_acc:.2f}.h5"

#Define checkpoint layers
checkpoint1 = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=False, mode='max')
checkpoint2 = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, mode='max')
rlrp = ReduceLROnPlateau(monitor='acc', factor=0.1, patience=patience, min_delta=0.000000001)

callbacks_list = [rlrp,checkpoint1,checkpoint2]

# %%
#Fit the data on model
history = model.fit_generator(generator=train_generator, epochs=epochs, steps_per_epoch=steps_per_epoch,
                              validation_data=valid_generator, validation_steps=validation_steps,
                              callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/200
# 8/8 [==============================] - 102s 13s/step - loss: 2.5360 - acc: 0.2188 - val_loss: 1.5229 - val_acc: 0.5000
#
# Epoch 00001: saving model to /content/drive/My Drive/model/model_01-0.22-0.50.h5
#
# Epoch 00001: acc improved from -inf to 0.21875, saving model to /content/drive/My Drive/model/model_01-0.22-0.50.h5
# Epoch 2/200
# 8/8 [==============================] - 89s 11s/step - loss: 1.6254 - acc: 0.4062 - val_loss: 1.3391 - val_acc: 0.5000
#
# Epoch 00002: saving model to /content/drive/My Drive/model/model_02-0.41-0.50.h5
#
# Epoch 00002: acc improved from 0.21875 to 0.40625, saving model to /content/drive/My Drive/model/model_02-0.41-0.50.h5
# Epoch 3/200
# 8/8 [==============================] - 88s 11s/step - loss: 1.3395 - acc: 0.4883 - val_loss: 1.0134 - val_acc: 0.6562
#
# Epoch 00003: saving model to /content/drive/My Drive/model/model_03-0.49-0.66.h5
#
# Epoch 00003: acc improved from 0.40625 to 0.48828, saving model to /content/drive/My Drive/model/model_03-0.49-0.66.h5
# Epoch 4/200
# 8/8 [==============================] - 87s 11s/step - loss: 1.2346 - acc: 0.5508 - val_loss: 0.8212 - val_acc: 0.6562
#
# Epoch 00004: saving model to /content/drive/My Drive/model/model_04-0.55-0.66.h5
#
# Epoch 00004: acc improved from 0.48828 to 0.55078, saving model to /content/drive/My Drive/model/model_04-0.55-0.66.h5
# Epoch 5/200
# 8/8 [==============================] - 81s 10s/step - loss: 1.1919 - acc: 0.5715 - val_loss: 1.8629 - val_acc: 0.3750
#
# Epoch 00005: saving model to /content/drive/My Drive/model/model_05-0.61-0.38.h5
#
# Epoch 00005: acc improved from 0.55078 to 0.61207, saving model to /content/drive/My Drive/model/model_05-0.61-0.38.h5
# Epoch 6/200
# 8/8 [==============================] - 85s 11s/step - loss: 1.4070 - acc: 0.4766 - val_loss: 0.8932 - val_acc: 0.6875
#
# Epoch 00006: saving model to /content/drive/My Drive/model/model_06-0.48-0.69.h5
#
# Epoch 00006: acc did not improve from 0.61207
# Epoch 7/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.9716 - acc: 0.6562 - val_loss: 0.8910 - val_acc: 0.6562
#
# Epoch 00007: saving model to /content/drive/My Drive/model/model_07-0.66-0.66.h5
#
# Epoch 00007: acc improved from 0.61207 to 0.65625, saving model to /content/drive/My Drive/model/model_07-0.66-0.66.h5
# Epoch 8/200
# 8/8 [==============================] - 87s 11s/step - loss: 1.0765 - acc: 0.6211 - val_loss: 0.5172 - val_acc: 0.8750
#
# Epoch 00008: saving model to /content/drive/My Drive/model/model_08-0.62-0.88.h5
#
# Epoch 00008: acc did not improve from 0.65625
# Epoch 9/200
# 8/8 [==============================] - 86s 11s/step - loss: 1.1142 - acc: 0.6289 - val_loss: 0.8693 - val_acc: 0.7188
#
# Epoch 00009: saving model to /content/drive/My Drive/model/model_09-0.63-0.72.h5
#
# Epoch 00009: acc did not improve from 0.65625
# Epoch 10/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.7712 - acc: 0.7227 - val_loss: 0.8555 - val_acc: 0.6875
#
# Epoch 00010: saving model to /content/drive/My Drive/model/model_10-0.72-0.69.h5
#
# Epoch 00010: acc improved from 0.65625 to 0.72266, saving model to /content/drive/My Drive/model/model_10-0.72-0.69.h5
# Epoch 11/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.8448 - acc: 0.6758 - val_loss: 1.0163 - val_acc: 0.7500
#
# Epoch 00011: saving model to /content/drive/My Drive/model/model_11-0.68-0.75.h5
#
# Epoch 00011: acc did not improve from 0.72266
# Epoch 12/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.8126 - acc: 0.6836 - val_loss: 0.8346 - val_acc: 0.6250
#
# Epoch 00012: saving model to /content/drive/My Drive/model/model_12-0.68-0.62.h5
#
# Epoch 00012: acc did not improve from 0.72266
# Epoch 13/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.9065 - acc: 0.6695 - val_loss: 0.4449 - val_acc: 0.8438
#
# Epoch 00013: saving model to /content/drive/My Drive/model/model_13-0.65-0.84.h5
#
# Epoch 00013: acc did not improve from 0.72266
# Epoch 14/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.9470 - acc: 0.6602 - val_loss: 1.0780 - val_acc: 0.5625
#
# Epoch 00014: saving model to /content/drive/My Drive/model/model_14-0.66-0.56.h5
#
# Epoch 00014: acc did not improve from 0.72266
# Epoch 15/200
# 8/8 [==============================] - 83s 10s/step - loss: 1.0423 - acc: 0.6200 - val_loss: 1.8204 - val_acc: 0.5312
#
# Epoch 00015: saving model to /content/drive/My Drive/model/model_15-0.64-0.53.h5
#
# Epoch 00015: acc did not improve from 0.72266
# Epoch 16/200
# 8/8 [==============================] - 89s 11s/step - loss: 1.0396 - acc: 0.7070 - val_loss: 0.9677 - val_acc: 0.6875
#
# Epoch 00016: saving model to /content/drive/My Drive/model/model_16-0.71-0.69.h5
#
# Epoch 00016: acc did not improve from 0.72266
# Epoch 17/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.8109 - acc: 0.7070 - val_loss: 0.7659 - val_acc: 0.7188
#
# Epoch 00017: saving model to /content/drive/My Drive/model/model_17-0.71-0.72.h5
#
# Epoch 00017: acc did not improve from 0.72266
# Epoch 18/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.9398 - acc: 0.6914 - val_loss: 1.0265 - val_acc: 0.5312
#
# Epoch 00018: saving model to /content/drive/My Drive/model/model_18-0.69-0.53.h5
#
# Epoch 00018: acc did not improve from 0.72266
# Epoch 19/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.8822 - acc: 0.6562 - val_loss: 0.6918 - val_acc: 0.7188
#
# Epoch 00019: saving model to /content/drive/My Drive/model/model_19-0.66-0.72.h5
#
# Epoch 00019: acc did not improve from 0.72266
# Epoch 20/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.9553 - acc: 0.6562 - val_loss: 0.9967 - val_acc: 0.6875
#
# Epoch 00020: saving model to /content/drive/My Drive/model/model_20-0.66-0.69.h5
#
# Epoch 00020: acc did not improve from 0.72266
# Epoch 21/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5707 - acc: 0.8086 - val_loss: 0.6777 - val_acc: 0.7500
#
# Epoch 00021: saving model to /content/drive/My Drive/model/model_21-0.81-0.75.h5
#
# Epoch 00021: acc improved from 0.72266 to 0.80859, saving model to /content/drive/My Drive/model/model_21-0.81-0.75.h5
# Epoch 22/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.6930 - acc: 0.7461 - val_loss: 0.9218 - val_acc: 0.3750
#
# Epoch 00022: saving model to /content/drive/My Drive/model/model_22-0.75-0.38.h5
#
# Epoch 00022: acc did not improve from 0.80859
# Epoch 23/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6398 - acc: 0.7383 - val_loss: 0.8338 - val_acc: 0.6250
#
# Epoch 00023: saving model to /content/drive/My Drive/model/model_23-0.74-0.62.h5
#
# Epoch 00023: acc did not improve from 0.80859
# Epoch 24/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6414 - acc: 0.8047 - val_loss: 0.5279 - val_acc: 0.7500
#
# Epoch 00024: saving model to /content/drive/My Drive/model/model_24-0.80-0.75.h5
#
# Epoch 00024: acc did not improve from 0.80859
# Epoch 25/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5505 - acc: 0.8008 - val_loss: 0.6872 - val_acc: 0.7188
#
# Epoch 00025: saving model to /content/drive/My Drive/model/model_25-0.80-0.72.h5
#
# Epoch 00025: acc did not improve from 0.80859
# Epoch 26/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6555 - acc: 0.7383 - val_loss: 0.7564 - val_acc: 0.7812
#
# Epoch 00026: saving model to /content/drive/My Drive/model/model_26-0.74-0.78.h5
#
# Epoch 00026: acc did not improve from 0.80859
# Epoch 27/200
# 8/8 [==============================] - 83s 10s/step - loss: 0.5993 - acc: 0.7734 - val_loss: 0.6251 - val_acc: 0.8125
#
# Epoch 00027: saving model to /content/drive/My Drive/model/model_27-0.77-0.81.h5
#
# Epoch 00027: acc did not improve from 0.80859
# Epoch 28/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.5860 - acc: 0.7949 - val_loss: 0.3598 - val_acc: 0.8750
#
# Epoch 00028: saving model to /content/drive/My Drive/model/model_28-0.81-0.88.h5
#
# Epoch 00028: acc improved from 0.80859 to 0.81034, saving model to /content/drive/My Drive/model/model_28-0.81-0.88.h5
# Epoch 29/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5735 - acc: 0.8164 - val_loss: 1.3302 - val_acc: 0.4688
#
# Epoch 00029: saving model to /content/drive/My Drive/model/model_29-0.82-0.47.h5
#
# Epoch 00029: acc improved from 0.81034 to 0.81641, saving model to /content/drive/My Drive/model/model_29-0.82-0.47.h5
# Epoch 30/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5407 - acc: 0.8203 - val_loss: 0.7028 - val_acc: 0.7500
#
# Epoch 00030: saving model to /content/drive/My Drive/model/model_30-0.82-0.75.h5
#
# Epoch 00030: acc improved from 0.81641 to 0.82031, saving model to /content/drive/My Drive/model/model_30-0.82-0.75.h5
# Epoch 31/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6032 - acc: 0.7695 - val_loss: 0.4904 - val_acc: 0.8750
#
# Epoch 00031: saving model to /content/drive/My Drive/model/model_31-0.77-0.88.h5
#
# Epoch 00031: acc did not improve from 0.82031
# Epoch 32/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.6919 - acc: 0.7737 - val_loss: 0.6988 - val_acc: 0.7812
#
# Epoch 00032: saving model to /content/drive/My Drive/model/model_32-0.78-0.78.h5
#
# Epoch 00032: acc did not improve from 0.82031
# Epoch 33/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.6504 - acc: 0.7500 - val_loss: 0.8728 - val_acc: 0.7500
#
# Epoch 00033: saving model to /content/drive/My Drive/model/model_33-0.75-0.75.h5
#
# Epoch 00033: acc did not improve from 0.82031
# Epoch 34/200
# 8/8 [==============================] - 84s 10s/step - loss: 0.6107 - acc: 0.7578 - val_loss: 0.7342 - val_acc: 0.7188
#
# Epoch 00034: saving model to /content/drive/My Drive/model/model_34-0.76-0.72.h5
#
# Epoch 00034: acc did not improve from 0.82031
# Epoch 35/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.7045 - acc: 0.7656 - val_loss: 0.7152 - val_acc: 0.6562
#
# Epoch 00035: saving model to /content/drive/My Drive/model/model_35-0.77-0.66.h5
#
# Epoch 00035: acc did not improve from 0.82031
# Epoch 36/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.5564 - acc: 0.7633 - val_loss: 1.1189 - val_acc: 0.5938
#
# Epoch 00036: saving model to /content/drive/My Drive/model/model_36-0.78-0.59.h5
#
# Epoch 00036: acc did not improve from 0.82031
# Epoch 37/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6162 - acc: 0.7539 - val_loss: 0.6994 - val_acc: 0.7812
#
# Epoch 00037: saving model to /content/drive/My Drive/model/model_37-0.75-0.78.h5
#
# Epoch 00037: acc did not improve from 0.82031
# Epoch 38/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5988 - acc: 0.7852 - val_loss: 0.6423 - val_acc: 0.7812
#
# Epoch 00038: saving model to /content/drive/My Drive/model/model_38-0.79-0.78.h5
#
# Epoch 00038: acc did not improve from 0.82031
# Epoch 39/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6069 - acc: 0.7812 - val_loss: 0.5952 - val_acc: 0.8750
#
# Epoch 00039: saving model to /content/drive/My Drive/model/model_39-0.78-0.88.h5
#
# Epoch 00039: acc did not improve from 0.82031
# Epoch 40/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5182 - acc: 0.7773 - val_loss: 0.5560 - val_acc: 0.7188
#
# Epoch 00040: saving model to /content/drive/My Drive/model/model_40-0.78-0.72.h5
#
# Epoch 00040: acc did not improve from 0.82031
# Epoch 41/200
# 8/8 [==============================] - 84s 10s/step - loss: 0.6929 - acc: 0.7461 - val_loss: 0.4961 - val_acc: 0.8438
#
# Epoch 00041: saving model to /content/drive/My Drive/model/model_41-0.75-0.84.h5
#
# Epoch 00041: acc did not improve from 0.82031
# Epoch 42/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6524 - acc: 0.7695 - val_loss: 0.6223 - val_acc: 0.7812
#
# Epoch 00042: saving model to /content/drive/My Drive/model/model_42-0.77-0.78.h5
#
# Epoch 00042: acc did not improve from 0.82031
# Epoch 43/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6081 - acc: 0.7773 - val_loss: 0.5691 - val_acc: 0.8438
#
# Epoch 00043: saving model to /content/drive/My Drive/model/model_43-0.78-0.84.h5
#
# Epoch 00043: acc did not improve from 0.82031
# Epoch 44/200
# 8/8 [==============================] - 73s 9s/step - loss: 0.5354 - acc: 0.7906 - val_loss: 0.6198 - val_acc: 0.7500
#
# Epoch 00044: saving model to /content/drive/My Drive/model/model_44-0.77-0.75.h5
#
# Epoch 00044: acc did not improve from 0.82031
# Epoch 45/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6541 - acc: 0.7578 - val_loss: 0.7746 - val_acc: 0.7812
#
# Epoch 00045: saving model to /content/drive/My Drive/model/model_45-0.76-0.78.h5
#
# Epoch 00045: acc did not improve from 0.82031
# Epoch 46/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5793 - acc: 0.7969 - val_loss: 0.4873 - val_acc: 0.7500
#
# Epoch 00046: saving model to /content/drive/My Drive/model/model_46-0.80-0.75.h5
#
# Epoch 00046: acc did not improve from 0.82031
# Epoch 47/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5890 - acc: 0.8008 - val_loss: 0.4467 - val_acc: 0.8750
#
# Epoch 00047: saving model to /content/drive/My Drive/model/model_47-0.80-0.88.h5
#
# Epoch 00047: acc did not improve from 0.82031
# Epoch 48/200
# 8/8 [==============================] - 84s 10s/step - loss: 0.6501 - acc: 0.7812 - val_loss: 0.5007 - val_acc: 0.8438
#
# Epoch 00048: saving model to /content/drive/My Drive/model/model_48-0.78-0.84.h5
#
# Epoch 00048: acc did not improve from 0.82031
# Epoch 49/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6345 - acc: 0.7852 - val_loss: 0.7931 - val_acc: 0.7188
#
# Epoch 00049: saving model to /content/drive/My Drive/model/model_49-0.79-0.72.h5
#
# Epoch 00049: acc did not improve from 0.82031
# Epoch 50/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5862 - acc: 0.7969 - val_loss: 0.8339 - val_acc: 0.7188
#
# Epoch 00050: saving model to /content/drive/My Drive/model/model_50-0.80-0.72.h5
#
# Epoch 00050: acc did not improve from 0.82031
# Epoch 51/200
# 8/8 [==============================] - 79s 10s/step - loss: 0.6405 - acc: 0.7856 - val_loss: 0.7109 - val_acc: 0.7500
#
# Epoch 00051: saving model to /content/drive/My Drive/model/model_51-0.79-0.75.h5
#
# Epoch 00051: acc did not improve from 0.82031
# Epoch 52/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.5826 - acc: 0.8047 - val_loss: 1.0805 - val_acc: 0.5938
#
# Epoch 00052: saving model to /content/drive/My Drive/model/model_52-0.80-0.59.h5
#
# Epoch 00052: acc did not improve from 0.82031
# Epoch 53/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.5048 - acc: 0.8320 - val_loss: 0.4565 - val_acc: 0.7812
#
# Epoch 00053: saving model to /content/drive/My Drive/model/model_53-0.83-0.78.h5
#
# Epoch 00053: acc improved from 0.82031 to 0.83203, saving model to /content/drive/My Drive/model/model_53-0.83-0.78.h5
# Epoch 54/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6434 - acc: 0.7773 - val_loss: 0.6928 - val_acc: 0.7188
#
# Epoch 00054: saving model to /content/drive/My Drive/model/model_54-0.78-0.72.h5
#
# Epoch 00054: acc did not improve from 0.83203
# Epoch 55/200
# 8/8 [==============================] - 78s 10s/step - loss: 0.6224 - acc: 0.7812 - val_loss: 1.2066 - val_acc: 0.6250
#
# Epoch 00055: saving model to /content/drive/My Drive/model/model_55-0.78-0.62.h5
#
# Epoch 00055: acc did not improve from 0.83203
# Epoch 56/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5747 - acc: 0.7891 - val_loss: 0.8486 - val_acc: 0.7500
#
# Epoch 00056: saving model to /content/drive/My Drive/model/model_56-0.79-0.75.h5
#
# Epoch 00056: acc did not improve from 0.83203
# Epoch 57/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5900 - acc: 0.7969 - val_loss: 0.5606 - val_acc: 0.8125
#
# Epoch 00057: saving model to /content/drive/My Drive/model/model_57-0.80-0.81.h5
#
# Epoch 00057: acc did not improve from 0.83203
# Epoch 58/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.5427 - acc: 0.7999 - val_loss: 1.4065 - val_acc: 0.4375
#
# Epoch 00058: saving model to /content/drive/My Drive/model/model_58-0.79-0.44.h5
#
# Epoch 00058: acc did not improve from 0.83203
# Epoch 59/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5898 - acc: 0.7695 - val_loss: 0.5673 - val_acc: 0.8125
#
# Epoch 00059: saving model to /content/drive/My Drive/model/model_59-0.77-0.81.h5
#
# Epoch 00059: acc did not improve from 0.83203
# Epoch 60/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5516 - acc: 0.8086 - val_loss: 0.5777 - val_acc: 0.7500
#
# Epoch 00060: saving model to /content/drive/My Drive/model/model_60-0.81-0.75.h5
#
# Epoch 00060: acc did not improve from 0.83203
# Epoch 61/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5724 - acc: 0.7852 - val_loss: 0.5158 - val_acc: 0.7812
#
# Epoch 00061: saving model to /content/drive/My Drive/model/model_61-0.79-0.78.h5
#
# Epoch 00061: acc did not improve from 0.83203
# Epoch 62/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5900 - acc: 0.7656 - val_loss: 0.4510 - val_acc: 0.8125
#
# Epoch 00062: saving model to /content/drive/My Drive/model/model_62-0.77-0.81.h5
#
# Epoch 00062: acc did not improve from 0.83203
# Epoch 63/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.6681 - acc: 0.7695 - val_loss: 0.6024 - val_acc: 0.7812
#
# Epoch 00063: saving model to /content/drive/My Drive/model/model_63-0.77-0.78.h5
#
# Epoch 00063: acc did not improve from 0.83203
# Epoch 64/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.5400 - acc: 0.8008 - val_loss: 0.7699 - val_acc: 0.8125
#
# Epoch 00064: saving model to /content/drive/My Drive/model/model_64-0.80-0.81.h5
#
# Epoch 00064: acc did not improve from 0.83203
# Epoch 65/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6314 - acc: 0.7539 - val_loss: 0.7759 - val_acc: 0.6875
#
# Epoch 00065: saving model to /content/drive/My Drive/model/model_65-0.75-0.69.h5
#
# Epoch 00065: acc did not improve from 0.83203
# Epoch 66/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.5657 - acc: 0.7891 - val_loss: 0.3147 - val_acc: 0.7500
#
# Epoch 00066: saving model to /content/drive/My Drive/model/model_66-0.79-0.75.h5
#
# Epoch 00066: acc did not improve from 0.83203
# Epoch 67/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6055 - acc: 0.7773 - val_loss: 1.0368 - val_acc: 0.6875
#
# Epoch 00067: saving model to /content/drive/My Drive/model/model_67-0.78-0.69.h5
#
# Epoch 00067: acc did not improve from 0.83203
# Epoch 68/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6066 - acc: 0.7656 - val_loss: 0.8650 - val_acc: 0.6875
#
# Epoch 00068: saving model to /content/drive/My Drive/model/model_68-0.77-0.69.h5
#
# Epoch 00068: acc did not improve from 0.83203
# Epoch 69/200
# 8/8 [==============================] - 78s 10s/step - loss: 0.6563 - acc: 0.7148 - val_loss: 0.6604 - val_acc: 0.7500
#
# Epoch 00069: saving model to /content/drive/My Drive/model/model_69-0.75-0.75.h5
#
# Epoch 00069: acc did not improve from 0.83203
# Epoch 70/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5790 - acc: 0.7891 - val_loss: 0.7091 - val_acc: 0.7812
#
# Epoch 00070: saving model to /content/drive/My Drive/model/model_70-0.79-0.78.h5
#
# Epoch 00070: acc did not improve from 0.83203
# Epoch 71/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5781 - acc: 0.8008 - val_loss: 0.6342 - val_acc: 0.7500
#
# Epoch 00071: saving model to /content/drive/My Drive/model/model_71-0.80-0.75.h5
#
# Epoch 00071: acc did not improve from 0.83203
# Epoch 72/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6277 - acc: 0.7461 - val_loss: 0.7348 - val_acc: 0.7500
#
# Epoch 00072: saving model to /content/drive/My Drive/model/model_72-0.75-0.75.h5
#
# Epoch 00072: acc did not improve from 0.83203
# Epoch 73/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5509 - acc: 0.8008 - val_loss: 0.8270 - val_acc: 0.6250
#
# Epoch 00073: saving model to /content/drive/My Drive/model/model_73-0.80-0.62.h5
#
# Epoch 00073: acc did not improve from 0.83203
# Epoch 74/200
# 8/8 [==============================] - 79s 10s/step - loss: 0.6051 - acc: 0.7683 - val_loss: 0.5873 - val_acc: 0.8125
#
# Epoch 00074: saving model to /content/drive/My Drive/model/model_74-0.76-0.81.h5
#
# Epoch 00074: acc did not improve from 0.83203
# Epoch 75/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5788 - acc: 0.8203 - val_loss: 0.5828 - val_acc: 0.7812
#
# Epoch 00075: saving model to /content/drive/My Drive/model/model_75-0.82-0.78.h5
#
# Epoch 00075: acc did not improve from 0.83203
# Epoch 76/200
# 8/8 [==============================] - 84s 10s/step - loss: 0.5525 - acc: 0.7930 - val_loss: 0.4225 - val_acc: 0.8125
#
# Epoch 00076: saving model to /content/drive/My Drive/model/model_76-0.79-0.81.h5
#
# Epoch 00076: acc did not improve from 0.83203
# Epoch 77/200
# 8/8 [==============================] - 79s 10s/step - loss: 0.5448 - acc: 0.7969 - val_loss: 0.3619 - val_acc: 0.7500
#
# Epoch 00077: saving model to /content/drive/My Drive/model/model_77-0.80-0.75.h5
#
# Epoch 00077: acc did not improve from 0.83203
# Epoch 78/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.6131 - acc: 0.7773 - val_loss: 1.1022 - val_acc: 0.6562
#
# Epoch 00078: saving model to /content/drive/My Drive/model/model_78-0.78-0.66.h5
#
# Epoch 00078: acc did not improve from 0.83203
# Epoch 79/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6015 - acc: 0.7656 - val_loss: 0.5696 - val_acc: 0.8125
#
# Epoch 00079: saving model to /content/drive/My Drive/model/model_79-0.77-0.81.h5
#
# Epoch 00079: acc did not improve from 0.83203
# Epoch 80/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6507 - acc: 0.7500 - val_loss: 0.6203 - val_acc: 0.6875
#
# Epoch 00080: saving model to /content/drive/My Drive/model/model_80-0.75-0.69.h5
#
# Epoch 00080: acc did not improve from 0.83203
# Epoch 81/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5135 - acc: 0.8125 - val_loss: 0.6500 - val_acc: 0.7188
#
# Epoch 00081: saving model to /content/drive/My Drive/model/model_81-0.81-0.72.h5
#
# Epoch 00081: acc did not improve from 0.83203
# Epoch 82/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6469 - acc: 0.7695 - val_loss: 0.7628 - val_acc: 0.7500
#
# Epoch 00082: saving model to /content/drive/My Drive/model/model_82-0.77-0.75.h5
#
# Epoch 00082: acc did not improve from 0.83203
# Epoch 83/200
# 8/8 [==============================] - 84s 11s/step - loss: 0.5834 - acc: 0.7930 - val_loss: 0.6516 - val_acc: 0.8125
#
# Epoch 00083: saving model to /content/drive/My Drive/model/model_83-0.79-0.81.h5
#
# Epoch 00083: acc did not improve from 0.83203
# Epoch 84/200
# 8/8 [==============================] - 79s 10s/step - loss: 0.5529 - acc: 0.8290 - val_loss: 0.5631 - val_acc: 0.6875
#
# Epoch 00084: saving model to /content/drive/My Drive/model/model_84-0.84-0.69.h5
#
# Epoch 00084: acc improved from 0.83203 to 0.83621, saving model to /content/drive/My Drive/model/model_84-0.84-0.69.h5
# Epoch 85/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.6486 - acc: 0.7773 - val_loss: 0.3478 - val_acc: 0.8750
#
# Epoch 00085: saving model to /content/drive/My Drive/model/model_85-0.78-0.88.h5
#
# Epoch 00085: acc did not improve from 0.83621
# Epoch 86/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5460 - acc: 0.7852 - val_loss: 0.2767 - val_acc: 0.9375
#
# Epoch 00086: saving model to /content/drive/My Drive/model/model_86-0.79-0.94.h5
#
# Epoch 00086: acc did not improve from 0.83621
# Epoch 87/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6363 - acc: 0.7773 - val_loss: 1.4757 - val_acc: 0.5000
#
# Epoch 00087: saving model to /content/drive/My Drive/model/model_87-0.78-0.50.h5
#
# Epoch 00087: acc did not improve from 0.83621
# Epoch 88/200
# 8/8 [==============================] - 74s 9s/step - loss: 0.6103 - acc: 0.7751 - val_loss: 0.5231 - val_acc: 0.7500
#
# Epoch 00088: saving model to /content/drive/My Drive/model/model_88-0.79-0.75.h5
#
# Epoch 00088: acc did not improve from 0.83621
# Epoch 89/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6583 - acc: 0.7656 - val_loss: 0.8149 - val_acc: 0.7188
#
# Epoch 00089: saving model to /content/drive/My Drive/model/model_89-0.77-0.72.h5
#
# Epoch 00089: acc did not improve from 0.83621
# Epoch 90/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6081 - acc: 0.7812 - val_loss: 0.7044 - val_acc: 0.6875
#
# Epoch 00090: saving model to /content/drive/My Drive/model/model_90-0.78-0.69.h5
#
# Epoch 00090: acc did not improve from 0.83621
# Epoch 91/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5650 - acc: 0.7891 - val_loss: 0.5245 - val_acc: 0.7812
#
# Epoch 00091: saving model to /content/drive/My Drive/model/model_91-0.79-0.78.h5
#
# Epoch 00091: acc did not improve from 0.83621
# Epoch 92/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6377 - acc: 0.7656 - val_loss: 0.5609 - val_acc: 0.8438
#
# Epoch 00092: saving model to /content/drive/My Drive/model/model_92-0.77-0.84.h5
#
# Epoch 00092: acc did not improve from 0.83621
# Epoch 93/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.6378 - acc: 0.7856 - val_loss: 0.9428 - val_acc: 0.6875
#
# Epoch 00093: saving model to /content/drive/My Drive/model/model_93-0.79-0.69.h5
#
# Epoch 00093: acc did not improve from 0.83621
# Epoch 94/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5907 - acc: 0.7812 - val_loss: 0.5180 - val_acc: 0.7812
#
# Epoch 00094: saving model to /content/drive/My Drive/model/model_94-0.78-0.78.h5
#
# Epoch 00094: acc did not improve from 0.83621
# Epoch 95/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6363 - acc: 0.7656 - val_loss: 0.6156 - val_acc: 0.7500
#
# Epoch 00095: saving model to /content/drive/My Drive/model/model_95-0.77-0.75.h5
#
# Epoch 00095: acc did not improve from 0.83621
# Epoch 96/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6164 - acc: 0.7891 - val_loss: 0.7357 - val_acc: 0.7188
#
# Epoch 00096: saving model to /content/drive/My Drive/model/model_96-0.79-0.72.h5
#
# Epoch 00096: acc did not improve from 0.83621
# Epoch 97/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.5428 - acc: 0.8008 - val_loss: 0.7308 - val_acc: 0.7188
#
# Epoch 00097: saving model to /content/drive/My Drive/model/model_97-0.80-0.72.h5
#
# Epoch 00097: acc did not improve from 0.83621
# Epoch 98/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5515 - acc: 0.7969 - val_loss: 0.8407 - val_acc: 0.7500
#
# Epoch 00098: saving model to /content/drive/My Drive/model/model_98-0.80-0.75.h5
#
# Epoch 00098: acc did not improve from 0.83621
# Epoch 99/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.4925 - acc: 0.8594 - val_loss: 0.6489 - val_acc: 0.7500
#
# Epoch 00099: saving model to /content/drive/My Drive/model/model_99-0.86-0.75.h5
#
# Epoch 00099: acc improved from 0.83621 to 0.85938, saving model to /content/drive/My Drive/model/model_99-0.86-0.75.h5
# Epoch 100/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6331 - acc: 0.7773 - val_loss: 0.7188 - val_acc: 0.7812
#
# Epoch 00100: saving model to /content/drive/My Drive/model/model_100-0.78-0.78.h5
#
# Epoch 00100: acc did not improve from 0.85938
# Epoch 101/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6344 - acc: 0.7852 - val_loss: 0.8768 - val_acc: 0.6875
#
# Epoch 00101: saving model to /content/drive/My Drive/model/model_101-0.79-0.69.h5
#
# Epoch 00101: acc did not improve from 0.85938
# Epoch 102/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5704 - acc: 0.7930 - val_loss: 0.6911 - val_acc: 0.7812
#
# Epoch 00102: saving model to /content/drive/My Drive/model/model_102-0.79-0.78.h5
#
# Epoch 00102: acc did not improve from 0.85938
# Epoch 103/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.6078 - acc: 0.7856 - val_loss: 0.7421 - val_acc: 0.7188
#
# Epoch 00103: saving model to /content/drive/My Drive/model/model_103-0.79-0.72.h5
#
# Epoch 00103: acc did not improve from 0.85938
# Epoch 104/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.6360 - acc: 0.7344 - val_loss: 0.5885 - val_acc: 0.6875
#
# Epoch 00104: saving model to /content/drive/My Drive/model/model_104-0.73-0.69.h5
#
# Epoch 00104: acc did not improve from 0.85938
# Epoch 105/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.5407 - acc: 0.8086 - val_loss: 0.6442 - val_acc: 0.7500
#
# Epoch 00105: saving model to /content/drive/My Drive/model/model_105-0.81-0.75.h5
#
# Epoch 00105: acc did not improve from 0.85938
# Epoch 106/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5901 - acc: 0.7969 - val_loss: 0.7383 - val_acc: 0.7188
#
# Epoch 00106: saving model to /content/drive/My Drive/model/model_106-0.80-0.72.h5
#
# Epoch 00106: acc did not improve from 0.85938
# Epoch 107/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6002 - acc: 0.7969 - val_loss: 0.6330 - val_acc: 0.7812
#
# Epoch 00107: saving model to /content/drive/My Drive/model/model_107-0.80-0.78.h5
#
# Epoch 00107: acc did not improve from 0.85938
# Epoch 108/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.5820 - acc: 0.8064 - val_loss: 0.9639 - val_acc: 0.6562
#
# Epoch 00108: saving model to /content/drive/My Drive/model/model_108-0.79-0.66.h5
#
# Epoch 00108: acc did not improve from 0.85938
# Epoch 109/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5435 - acc: 0.7812 - val_loss: 0.5039 - val_acc: 0.8125
#
# Epoch 00109: saving model to /content/drive/My Drive/model/model_109-0.78-0.81.h5
#
# Epoch 00109: acc did not improve from 0.85938
# Epoch 110/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.6355 - acc: 0.7656 - val_loss: 0.2002 - val_acc: 1.0000
#
# Epoch 00110: saving model to /content/drive/My Drive/model/model_110-0.77-1.00.h5
#
# Epoch 00110: acc did not improve from 0.85938
# Epoch 111/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5839 - acc: 0.8047 - val_loss: 0.5692 - val_acc: 0.8750
#
# Epoch 00111: saving model to /content/drive/My Drive/model/model_111-0.80-0.88.h5
#
# Epoch 00111: acc did not improve from 0.85938
# Epoch 112/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.6738 - acc: 0.7617 - val_loss: 0.5891 - val_acc: 0.7812
#
# Epoch 00112: saving model to /content/drive/My Drive/model/model_112-0.76-0.78.h5
#
# Epoch 00112: acc did not improve from 0.85938
# Epoch 113/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5670 - acc: 0.7656 - val_loss: 0.8169 - val_acc: 0.6875
#
# Epoch 00113: saving model to /content/drive/My Drive/model/model_113-0.77-0.69.h5
#
# Epoch 00113: acc did not improve from 0.85938
# Epoch 114/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6885 - acc: 0.7344 - val_loss: 0.7654 - val_acc: 0.7500
#
# Epoch 00114: saving model to /content/drive/My Drive/model/model_114-0.73-0.75.h5
#
# Epoch 00114: acc did not improve from 0.85938
# Epoch 115/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6333 - acc: 0.7852 - val_loss: 0.7763 - val_acc: 0.6250
#
# Epoch 00115: saving model to /content/drive/My Drive/model/model_115-0.79-0.62.h5
#
# Epoch 00115: acc did not improve from 0.85938
# Epoch 116/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6073 - acc: 0.7930 - val_loss: 0.5620 - val_acc: 0.8125
#
# Epoch 00116: saving model to /content/drive/My Drive/model/model_116-0.79-0.81.h5
#
# Epoch 00116: acc did not improve from 0.85938
# Epoch 117/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5559 - acc: 0.8008 - val_loss: 0.7642 - val_acc: 0.7500
#
# Epoch 00117: saving model to /content/drive/My Drive/model/model_117-0.80-0.75.h5
#
# Epoch 00117: acc did not improve from 0.85938
# Epoch 118/200
# 8/8 [==============================] - 78s 10s/step - loss: 0.4872 - acc: 0.8434 - val_loss: 0.6694 - val_acc: 0.7188
#
# Epoch 00118: saving model to /content/drive/My Drive/model/model_118-0.84-0.72.h5
#
# Epoch 00118: acc did not improve from 0.85938
# Epoch 119/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.5933 - acc: 0.7930 - val_loss: 0.5477 - val_acc: 0.7500
#
# Epoch 00119: saving model to /content/drive/My Drive/model/model_119-0.79-0.75.h5
#
# Epoch 00119: acc did not improve from 0.85938
# Epoch 120/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5788 - acc: 0.8008 - val_loss: 0.8890 - val_acc: 0.6562
#
# Epoch 00120: saving model to /content/drive/My Drive/model/model_120-0.80-0.66.h5
#
# Epoch 00120: acc did not improve from 0.85938
# Epoch 121/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.5932 - acc: 0.7812 - val_loss: 0.8050 - val_acc: 0.8750
#
# Epoch 00121: saving model to /content/drive/My Drive/model/model_121-0.78-0.88.h5
#
# Epoch 00121: acc did not improve from 0.85938
# Epoch 122/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6335 - acc: 0.7695 - val_loss: 0.6743 - val_acc: 0.8438
#
# Epoch 00122: saving model to /content/drive/My Drive/model/model_122-0.77-0.84.h5
#
# Epoch 00122: acc did not improve from 0.85938
# Epoch 123/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5510 - acc: 0.8008 - val_loss: 0.4919 - val_acc: 0.7812
#
# Epoch 00123: saving model to /content/drive/My Drive/model/model_123-0.80-0.78.h5
#
# Epoch 00123: acc did not improve from 0.85938
# Epoch 124/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.6760 - acc: 0.7830 - val_loss: 0.6041 - val_acc: 0.7812
#
# Epoch 00124: saving model to /content/drive/My Drive/model/model_124-0.80-0.78.h5
#
# Epoch 00124: acc did not improve from 0.85938
# Epoch 125/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.5964 - acc: 0.7891 - val_loss: 0.6153 - val_acc: 0.6875
#
# Epoch 00125: saving model to /content/drive/My Drive/model/model_125-0.79-0.69.h5
#
# Epoch 00125: acc did not improve from 0.85938
# Epoch 126/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6705 - acc: 0.7383 - val_loss: 0.5008 - val_acc: 0.8125
#
# Epoch 00126: saving model to /content/drive/My Drive/model/model_126-0.74-0.81.h5
#
# Epoch 00126: acc did not improve from 0.85938
# Epoch 127/200
# 8/8 [==============================] - 92s 11s/step - loss: 0.5430 - acc: 0.8047 - val_loss: 0.5937 - val_acc: 0.7812
#
# Epoch 00127: saving model to /content/drive/My Drive/model/model_127-0.80-0.78.h5
#
# Epoch 00127: acc did not improve from 0.85938
# Epoch 128/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6145 - acc: 0.7852 - val_loss: 0.8614 - val_acc: 0.7188
#
# Epoch 00128: saving model to /content/drive/My Drive/model/model_128-0.79-0.72.h5
#
# Epoch 00128: acc did not improve from 0.85938
# Epoch 129/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5995 - acc: 0.7891 - val_loss: 0.7453 - val_acc: 0.6875
#
# Epoch 00129: saving model to /content/drive/My Drive/model/model_129-0.79-0.69.h5
#
# Epoch 00129: acc did not improve from 0.85938
# Epoch 130/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.5997 - acc: 0.7460 - val_loss: 0.9012 - val_acc: 0.6875
#
# Epoch 00130: saving model to /content/drive/My Drive/model/model_130-0.75-0.69.h5
#
# Epoch 00130: acc did not improve from 0.85938
# Epoch 131/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.4724 - acc: 0.8320 - val_loss: 0.8100 - val_acc: 0.7188
#
# Epoch 00131: saving model to /content/drive/My Drive/model/model_131-0.83-0.72.h5
#
# Epoch 00131: acc did not improve from 0.85938
# Epoch 132/200
# 8/8 [==============================] - 78s 10s/step - loss: 0.6028 - acc: 0.7852 - val_loss: 1.4104 - val_acc: 0.5000
#
# Epoch 00132: saving model to /content/drive/My Drive/model/model_132-0.79-0.50.h5
#
# Epoch 00132: acc did not improve from 0.85938
# Epoch 133/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.5120 - acc: 0.8477 - val_loss: 0.6552 - val_acc: 0.7188
#
# Epoch 00133: saving model to /content/drive/My Drive/model/model_133-0.85-0.72.h5
#
# Epoch 00133: acc did not improve from 0.85938
# Epoch 134/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5529 - acc: 0.8008 - val_loss: 0.5946 - val_acc: 0.7812
#
# Epoch 00134: saving model to /content/drive/My Drive/model/model_134-0.80-0.78.h5
#
# Epoch 00134: acc did not improve from 0.85938
# Epoch 135/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5976 - acc: 0.7930 - val_loss: 0.3437 - val_acc: 0.8438
#
# Epoch 00135: saving model to /content/drive/My Drive/model/model_135-0.79-0.84.h5
#
# Epoch 00135: acc did not improve from 0.85938
# Epoch 136/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5604 - acc: 0.7969 - val_loss: 0.7975 - val_acc: 0.6875
#
# Epoch 00136: saving model to /content/drive/My Drive/model/model_136-0.80-0.69.h5
#
# Epoch 00136: acc did not improve from 0.85938
# Epoch 137/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6115 - acc: 0.7930 - val_loss: 0.5113 - val_acc: 0.7812
#
# Epoch 00137: saving model to /content/drive/My Drive/model/model_137-0.79-0.78.h5
#
# Epoch 00137: acc did not improve from 0.85938
# Epoch 138/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5680 - acc: 0.7891 - val_loss: 0.5773 - val_acc: 0.8125
#
# Epoch 00138: saving model to /content/drive/My Drive/model/model_138-0.79-0.81.h5
#
# Epoch 00138: acc did not improve from 0.85938
# Epoch 139/200
# 8/8 [==============================] - 78s 10s/step - loss: 0.5760 - acc: 0.8039 - val_loss: 0.7980 - val_acc: 0.6562
#
# Epoch 00139: saving model to /content/drive/My Drive/model/model_139-0.80-0.66.h5
#
# Epoch 00139: acc did not improve from 0.85938
# Epoch 140/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5565 - acc: 0.7891 - val_loss: 0.8345 - val_acc: 0.6875
#
# Epoch 00140: saving model to /content/drive/My Drive/model/model_140-0.79-0.69.h5
#
# Epoch 00140: acc did not improve from 0.85938
# Epoch 141/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.6526 - acc: 0.7777 - val_loss: 0.8013 - val_acc: 0.7500
#
# Epoch 00141: saving model to /content/drive/My Drive/model/model_141-0.78-0.75.h5
#
# Epoch 00141: acc did not improve from 0.85938
# Epoch 142/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6000 - acc: 0.7852 - val_loss: 0.8261 - val_acc: 0.7500
#
# Epoch 00142: saving model to /content/drive/My Drive/model/model_142-0.79-0.75.h5
#
# Epoch 00142: acc did not improve from 0.85938
# Epoch 143/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.5255 - acc: 0.8086 - val_loss: 1.6446 - val_acc: 0.6250
#
# Epoch 00143: saving model to /content/drive/My Drive/model/model_143-0.81-0.62.h5
#
# Epoch 00143: acc did not improve from 0.85938
# Epoch 144/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5582 - acc: 0.8047 - val_loss: 0.5410 - val_acc: 0.8125
#
# Epoch 00144: saving model to /content/drive/My Drive/model/model_144-0.80-0.81.h5
#
# Epoch 00144: acc did not improve from 0.85938
# Epoch 145/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6656 - acc: 0.7617 - val_loss: 0.8285 - val_acc: 0.7812
#
# Epoch 00145: saving model to /content/drive/My Drive/model/model_145-0.76-0.78.h5
#
# Epoch 00145: acc did not improve from 0.85938
# Epoch 146/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.5487 - acc: 0.8047 - val_loss: 0.5567 - val_acc: 0.7500
#
# Epoch 00146: saving model to /content/drive/My Drive/model/model_146-0.80-0.75.h5
#
# Epoch 00146: acc did not improve from 0.85938
# Epoch 147/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5661 - acc: 0.7969 - val_loss: 0.4107 - val_acc: 0.8125
#
# Epoch 00147: saving model to /content/drive/My Drive/model/model_147-0.80-0.81.h5
#
# Epoch 00147: acc did not improve from 0.85938
# Epoch 148/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5504 - acc: 0.7930 - val_loss: 0.8180 - val_acc: 0.7188
#
# Epoch 00148: saving model to /content/drive/My Drive/model/model_148-0.79-0.72.h5
#
# Epoch 00148: acc did not improve from 0.85938
# Epoch 149/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5771 - acc: 0.8086 - val_loss: 0.9201 - val_acc: 0.6562
#
# Epoch 00149: saving model to /content/drive/My Drive/model/model_149-0.81-0.66.h5
#
# Epoch 00149: acc did not improve from 0.85938
# Epoch 150/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.5869 - acc: 0.8093 - val_loss: 0.8420 - val_acc: 0.7500
#
# Epoch 00150: saving model to /content/drive/My Drive/model/model_150-0.81-0.75.h5
#
# Epoch 00150: acc did not improve from 0.85938
# Epoch 151/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.6138 - acc: 0.7656 - val_loss: 0.7531 - val_acc: 0.6875
#
# Epoch 00151: saving model to /content/drive/My Drive/model/model_151-0.77-0.69.h5
#
# Epoch 00151: acc did not improve from 0.85938
# Epoch 152/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5858 - acc: 0.7969 - val_loss: 0.5110 - val_acc: 0.8125
#
# Epoch 00152: saving model to /content/drive/My Drive/model/model_152-0.80-0.81.h5
#
# Epoch 00152: acc did not improve from 0.85938
# Epoch 153/200
# 8/8 [==============================] - 84s 10s/step - loss: 0.5269 - acc: 0.8281 - val_loss: 0.8190 - val_acc: 0.6875
#
# Epoch 00153: saving model to /content/drive/My Drive/model/model_153-0.83-0.69.h5
#
# Epoch 00153: acc did not improve from 0.85938
# Epoch 154/200
# 8/8 [==============================] - 78s 10s/step - loss: 0.5934 - acc: 0.7969 - val_loss: 0.6017 - val_acc: 0.6250
#
# Epoch 00154: saving model to /content/drive/My Drive/model/model_154-0.80-0.62.h5
#
# Epoch 00154: acc did not improve from 0.85938
# Epoch 155/200
# 8/8 [==============================] - 83s 10s/step - loss: 0.6486 - acc: 0.7856 - val_loss: 0.7165 - val_acc: 0.7812
#
# Epoch 00155: saving model to /content/drive/My Drive/model/model_155-0.79-0.78.h5
#
# Epoch 00155: acc did not improve from 0.85938
# Epoch 156/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6244 - acc: 0.7500 - val_loss: 0.6152 - val_acc: 0.7812
#
# Epoch 00156: saving model to /content/drive/My Drive/model/model_156-0.75-0.78.h5
#
# Epoch 00156: acc did not improve from 0.85938
# Epoch 157/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5997 - acc: 0.7969 - val_loss: 0.8452 - val_acc: 0.7500
#
# Epoch 00157: saving model to /content/drive/My Drive/model/model_157-0.80-0.75.h5
#
# Epoch 00157: acc did not improve from 0.85938
# Epoch 158/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6227 - acc: 0.7812 - val_loss: 0.8014 - val_acc: 0.7500
#
# Epoch 00158: saving model to /content/drive/My Drive/model/model_158-0.78-0.75.h5
#
# Epoch 00158: acc did not improve from 0.85938
# Epoch 159/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5713 - acc: 0.8008 - val_loss: 0.6904 - val_acc: 0.6875
#
# Epoch 00159: saving model to /content/drive/My Drive/model/model_159-0.80-0.69.h5
#
# Epoch 00159: acc did not improve from 0.85938
# Epoch 160/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.5855 - acc: 0.7656 - val_loss: 0.8498 - val_acc: 0.6562
#
# Epoch 00160: saving model to /content/drive/My Drive/model/model_160-0.77-0.66.h5
#
# Epoch 00160: acc did not improve from 0.85938
# Epoch 161/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6701 - acc: 0.7539 - val_loss: 0.5459 - val_acc: 0.8438
#
# Epoch 00161: saving model to /content/drive/My Drive/model/model_161-0.75-0.84.h5
#
# Epoch 00161: acc did not improve from 0.85938
# Epoch 162/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5405 - acc: 0.8359 - val_loss: 0.5915 - val_acc: 0.7500
#
# Epoch 00162: saving model to /content/drive/My Drive/model/model_162-0.84-0.75.h5
#
# Epoch 00162: acc did not improve from 0.85938
# Epoch 163/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6091 - acc: 0.7461 - val_loss: 0.7841 - val_acc: 0.7188
#
# Epoch 00163: saving model to /content/drive/My Drive/model/model_163-0.75-0.72.h5
#
# Epoch 00163: acc did not improve from 0.85938
# Epoch 164/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6447 - acc: 0.7617 - val_loss: 0.6718 - val_acc: 0.6562
#
# Epoch 00164: saving model to /content/drive/My Drive/model/model_164-0.76-0.66.h5
#
# Epoch 00164: acc did not improve from 0.85938
# Epoch 165/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.7025 - acc: 0.7500 - val_loss: 0.1555 - val_acc: 1.0000
#
# Epoch 00165: saving model to /content/drive/My Drive/model/model_165-0.75-1.00.h5
#
# Epoch 00165: acc did not improve from 0.85938
# Epoch 166/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.5737 - acc: 0.7999 - val_loss: 0.8155 - val_acc: 0.7812
#
# Epoch 00166: saving model to /content/drive/My Drive/model/model_166-0.79-0.78.h5
#
# Epoch 00166: acc did not improve from 0.85938
# Epoch 167/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.5360 - acc: 0.8203 - val_loss: 1.0470 - val_acc: 0.5625
#
# Epoch 00167: saving model to /content/drive/My Drive/model/model_167-0.82-0.56.h5
#
# Epoch 00167: acc did not improve from 0.85938
# Epoch 168/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5901 - acc: 0.7578 - val_loss: 0.7832 - val_acc: 0.7188
#
# Epoch 00168: saving model to /content/drive/My Drive/model/model_168-0.76-0.72.h5
#
# Epoch 00168: acc did not improve from 0.85938
# Epoch 169/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.7170 - acc: 0.7238 - val_loss: 0.5344 - val_acc: 0.8125
#
# Epoch 00169: saving model to /content/drive/My Drive/model/model_169-0.73-0.81.h5
#
# Epoch 00169: acc did not improve from 0.85938
# Epoch 170/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5081 - acc: 0.8359 - val_loss: 0.7069 - val_acc: 0.7500
#
# Epoch 00170: saving model to /content/drive/My Drive/model/model_170-0.84-0.75.h5
#
# Epoch 00170: acc did not improve from 0.85938
# Epoch 171/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6728 - acc: 0.7734 - val_loss: 0.4387 - val_acc: 0.8438
#
# Epoch 00171: saving model to /content/drive/My Drive/model/model_171-0.77-0.84.h5
#
# Epoch 00171: acc did not improve from 0.85938
# Epoch 172/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5944 - acc: 0.7891 - val_loss: 0.8258 - val_acc: 0.6250
#
# Epoch 00172: saving model to /content/drive/My Drive/model/model_172-0.79-0.62.h5
#
# Epoch 00172: acc did not improve from 0.85938
# Epoch 173/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5189 - acc: 0.8164 - val_loss: 0.5169 - val_acc: 0.7500
#
# Epoch 00173: saving model to /content/drive/My Drive/model/model_173-0.82-0.75.h5
#
# Epoch 00173: acc did not improve from 0.85938
# Epoch 174/200
# 8/8 [==============================] - 84s 11s/step - loss: 0.6240 - acc: 0.7812 - val_loss: 0.7284 - val_acc: 0.7500
#
# Epoch 00174: saving model to /content/drive/My Drive/model/model_174-0.78-0.75.h5
#
# Epoch 00174: acc did not improve from 0.85938
# Epoch 175/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5501 - acc: 0.7891 - val_loss: 0.6720 - val_acc: 0.7812
#
# Epoch 00175: saving model to /content/drive/My Drive/model/model_175-0.79-0.78.h5
#
# Epoch 00175: acc did not improve from 0.85938
# Epoch 176/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.5387 - acc: 0.7969 - val_loss: 0.3272 - val_acc: 1.0000
#
# Epoch 00176: saving model to /content/drive/My Drive/model/model_176-0.80-1.00.h5
#
# Epoch 00176: acc did not improve from 0.85938
# Epoch 177/200
# 8/8 [==============================] - 80s 10s/step - loss: 0.6590 - acc: 0.7407 - val_loss: 0.3571 - val_acc: 0.9062
#
# Epoch 00177: saving model to /content/drive/My Drive/model/model_177-0.73-0.91.h5
#
# Epoch 00177: acc did not improve from 0.85938
# Epoch 178/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5980 - acc: 0.7773 - val_loss: 0.6150 - val_acc: 0.8750
#
# Epoch 00178: saving model to /content/drive/My Drive/model/model_178-0.78-0.88.h5
#
# Epoch 00178: acc did not improve from 0.85938
# Epoch 179/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5451 - acc: 0.7852 - val_loss: 0.4759 - val_acc: 0.8125
#
# Epoch 00179: saving model to /content/drive/My Drive/model/model_179-0.79-0.81.h5
#
# Epoch 00179: acc did not improve from 0.85938
# Epoch 180/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5407 - acc: 0.8164 - val_loss: 0.6542 - val_acc: 0.6875
#
# Epoch 00180: saving model to /content/drive/My Drive/model/model_180-0.82-0.69.h5
#
# Epoch 00180: acc did not improve from 0.85938
# Epoch 181/200
# 8/8 [==============================] - 84s 11s/step - loss: 0.5696 - acc: 0.7812 - val_loss: 0.9542 - val_acc: 0.6875
#
# Epoch 00181: saving model to /content/drive/My Drive/model/model_181-0.78-0.69.h5
#
# Epoch 00181: acc did not improve from 0.85938
# Epoch 182/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5748 - acc: 0.7930 - val_loss: 0.7197 - val_acc: 0.7500
#
# Epoch 00182: saving model to /content/drive/My Drive/model/model_182-0.79-0.75.h5
#
# Epoch 00182: acc did not improve from 0.85938
# Epoch 183/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6764 - acc: 0.7695 - val_loss: 0.7868 - val_acc: 0.6875
#
# Epoch 00183: saving model to /content/drive/My Drive/model/model_183-0.77-0.69.h5
#
# Epoch 00183: acc did not improve from 0.85938
# Epoch 184/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.5384 - acc: 0.8164 - val_loss: 0.8504 - val_acc: 0.7188
#
# Epoch 00184: saving model to /content/drive/My Drive/model/model_184-0.82-0.72.h5
#
# Epoch 00184: acc did not improve from 0.85938
# Epoch 185/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5343 - acc: 0.8164 - val_loss: 0.6819 - val_acc: 0.6875
#
# Epoch 00185: saving model to /content/drive/My Drive/model/model_185-0.82-0.69.h5
#
# Epoch 00185: acc did not improve from 0.85938
# Epoch 186/200
# 8/8 [==============================] - 87s 11s/step - loss: 0.6630 - acc: 0.7578 - val_loss: 0.8266 - val_acc: 0.6562
#
# Epoch 00186: saving model to /content/drive/My Drive/model/model_186-0.76-0.66.h5
#
# Epoch 00186: acc did not improve from 0.85938
# Epoch 187/200
# 8/8 [==============================] - 74s 9s/step - loss: 0.6370 - acc: 0.7525 - val_loss: 0.9147 - val_acc: 0.6250
#
# Epoch 00187: saving model to /content/drive/My Drive/model/model_187-0.74-0.62.h5
#
# Epoch 00187: acc did not improve from 0.85938
# Epoch 188/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5407 - acc: 0.8125 - val_loss: 0.5861 - val_acc: 0.7188
#
# Epoch 00188: saving model to /content/drive/My Drive/model/model_188-0.81-0.72.h5
#
# Epoch 00188: acc did not improve from 0.85938
# Epoch 189/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.5705 - acc: 0.7773 - val_loss: 0.8448 - val_acc: 0.7500
#
# Epoch 00189: saving model to /content/drive/My Drive/model/model_189-0.78-0.75.h5
#
# Epoch 00189: acc did not improve from 0.85938
# Epoch 190/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6284 - acc: 0.7695 - val_loss: 1.0108 - val_acc: 0.6250
#
# Epoch 00190: saving model to /content/drive/My Drive/model/model_190-0.77-0.62.h5
#
# Epoch 00190: acc did not improve from 0.85938
# Epoch 191/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.4989 - acc: 0.8555 - val_loss: 0.3622 - val_acc: 0.8438
#
# Epoch 00191: saving model to /content/drive/My Drive/model/model_191-0.86-0.84.h5
#
# Epoch 00191: acc did not improve from 0.85938
# Epoch 192/200
# 8/8 [==============================] - 89s 11s/step - loss: 0.5156 - acc: 0.8164 - val_loss: 0.7705 - val_acc: 0.7188
#
# Epoch 00192: saving model to /content/drive/My Drive/model/model_192-0.82-0.72.h5
#
# Epoch 00192: acc did not improve from 0.85938
# Epoch 193/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6163 - acc: 0.7891 - val_loss: 0.6858 - val_acc: 0.7812
#
# Epoch 00193: saving model to /content/drive/My Drive/model/model_193-0.79-0.78.h5
#
# Epoch 00193: acc did not improve from 0.85938
# Epoch 194/200
# 8/8 [==============================] - 81s 10s/step - loss: 0.6036 - acc: 0.7906 - val_loss: 0.5913 - val_acc: 0.7500
#
# Epoch 00194: saving model to /content/drive/My Drive/model/model_194-0.77-0.75.h5
#
# Epoch 00194: acc did not improve from 0.85938
# Epoch 195/200
# 8/8 [==============================] - 85s 11s/step - loss: 0.6131 - acc: 0.7773 - val_loss: 0.7373 - val_acc: 0.7500
#
# Epoch 00195: saving model to /content/drive/My Drive/model/model_195-0.78-0.75.h5
#
# Epoch 00195: acc did not improve from 0.85938
# Epoch 196/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6009 - acc: 0.7617 - val_loss: 0.6833 - val_acc: 0.7812
#
# Epoch 00196: saving model to /content/drive/My Drive/model/model_196-0.76-0.78.h5
#
# Epoch 00196: acc did not improve from 0.85938
# Epoch 197/200
# 8/8 [==============================] - 86s 11s/step - loss: 0.5734 - acc: 0.8047 - val_loss: 0.7194 - val_acc: 0.7500
#
# Epoch 00197: saving model to /content/drive/My Drive/model/model_197-0.80-0.75.h5
#
# Epoch 00197: acc did not improve from 0.85938
# Epoch 198/200
# 8/8 [==============================] - 74s 9s/step - loss: 0.5683 - acc: 0.8118 - val_loss: 0.6369 - val_acc: 0.6250
#
# Epoch 00198: saving model to /content/drive/My Drive/model/model_198-0.81-0.62.h5
#
# Epoch 00198: acc did not improve from 0.85938
# Epoch 199/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.6081 - acc: 0.7852 - val_loss: 0.5681 - val_acc: 0.7500
#
# Epoch 00199: saving model to /content/drive/My Drive/model/model_199-0.79-0.75.h5
#
# Epoch 00199: acc did not improve from 0.85938
# Epoch 200/200
# 8/8 [==============================] - 88s 11s/step - loss: 0.5514 - acc: 0.7930 - val_loss: 0.7165 - val_acc: 0.7812
#
# Epoch 00200: saving model to /content/drive/My Drive/model/model_200-0.79-0.78.h5
#
# Epoch 00200: acc did not improve from 0.85938

# %%
#Download History as CSV to local drive
hist_df = pd.DataFrame(history.history) 
hist_df.to_csv('trainHistoryDict.csv')
files.download('trainHistoryDict.csv')

# %% [markdown]
# ## Test the model

# %% [markdown]
# ### Measure test accuracy of model

# %%
#Load the model for required Epoch
model1 = load_model('/content/drive/My Drive/model_47-0.80-0.88.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:350: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
#Reset the test generator
test_generator.reset()
#Evaluate the model on test generator
history1=model1.evaluate_generator(test_generator)

# %%
#Print the test accuracy
print(f'The test accuracy of the model is: {round(history1[1]*100,2)}%')
# Out:
# The test accuracy of the model is: 74.48%

# %%
#Get predictions on test data
Y_pred = model1.predict_generator(test_generator)
#Convert prediction scores to categorical values
y_pred = np.argmax(Y_pred, axis=1)

# %% [markdown]
# ### Plot confusion matrix

# %%
#Print plot title
print('Confusion Matrix')
#Calculate confusion matrix
cm = confusion_matrix(test_generator.classes, y_pred)
#Define plot space
fig, ax = plt.subplots()
#Plot the confusion matrix
im = ax.imshow(cm)
#Set Xticks
ax.set_xticks(np.arange(6)), ax.set_yticks(np.arange(6))
#Define the X tick labels
ax.set_xticklabels(list(LABELS_NUMBERS_REVERSE.values()), rotation=45, ha="right")
#Define the Y tick labels
ax.set_yticklabels(list(LABELS_NUMBERS_REVERSE.values()))
#Set y label
ax.set_ylabel('True')
#Set x label
ax.set_xlabel('Predicted')
#Calculate and display values
for i in range(36):
    ax.text(int(i/6),i%6,cm[i%6,int(i/6)], ha="center", va="center", color="w")
# Out:
# Confusion Matrix

# %% [markdown]
# ### View classification report

# %%
#Print the classification report
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=LABELS_NUMBERS_MAP))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#        trash       1.00      0.70      0.82        70
#      plastic       0.80      0.78      0.79        82
#        paper       0.88      0.53      0.66        68
#        metal       0.79      0.89      0.84       108
#        glass       0.54      0.96      0.69        74
#    cardboard       0.62      0.17      0.27        29
#
#     accuracy                           0.74       431
#    macro avg       0.77      0.67      0.68       431
# weighted avg       0.79      0.74      0.73       431

# %% [markdown]
# ### View misclassified samples

# %%
#Visualizing sample photos
import matplotlib.pyplot as plt
plt.figure(figsize=[25,15])
for k,i in enumerate(random.choices(np.where(y_pred == y_test)[0].tolist(),k=5)):
    plt.subplot(1,5,k+1)
    plt.imshow(X_train[i])
    plt.xticks(())
    plt.yticks(())
    plt.xlabel("True: {}, Predicted: {}".format(LABELS_NUMBERS_REVERSE[y_train[i]],LABELS_NUMBERS_REVERSE[y_test[i]]))
plt.show();
